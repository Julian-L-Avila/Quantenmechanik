# %%
import pandas as pd
import numpy as np
from scipy.signal import find_peaks
import os
import matplotlib.pyplot as plt
import glob
import shutil # Para eliminar directorios

def extract_normal_mode_windows_optimized(file_path, tao):
    """
    Extrae ventanas de tiempo donde los péndulos oscilan en un modo normal,
    con la condición de no tener picos extra en P2 y P3 entre picos de P1.
    Retorna la duración total de las ventanas encontradas y los datos/metadatos.

    Args:
        file_path (str): Ruta al archivo de datos TSV.
        tao (float): El ancho de la ventana temporal (en segundos) alrededor del pico
                     del péndulo 1 para buscar picos en los otros péndulos.

    Returns:
        tuple: (total_window_duration, list_of_windows_data, list_of_windows_metadata)
               donde list_of_windows_data es una lista de DataFrames y list_of_windows_metadata
               contiene (ti, tf, output_filename, plot_filename, duration) para cada ventana.
               Retorna (0, [], []) si no se encontraron ventanas.
    """
    
    try:
        df = pd.read_csv(file_path, sep='\t', header=None, names=['time', 'pendulum1', 'pendulum2', 'pendulum3'])
    except FileNotFoundError:
        print(f"Error: El archivo '{file_path}' no fue encontrado.")
        return 0, [], []

    time = df['time'].values
    pendulum1 = df['pendulum1'].values
    pendulum2 = df['pendulum2'].values
    pendulum3 = df['pendulum3'].values

    peaks_p1_max, _ = find_peaks(pendulum1)
    peaks_p1_min, _ = find_peaks(-pendulum1)
    all_peaks_p1_indices = np.sort(np.concatenate((peaks_p1_max, peaks_p1_min)))

    if len(all_peaks_p1_indices) < 2:
        return 0, [], []

    all_peaks_p2_indices_max, _ = find_peaks(pendulum2)
    all_peaks_p2_indices_min, _ = find_peaks(-pendulum2)
    all_peaks_p2_indices = np.sort(np.concatenate((all_peaks_p2_indices_max, all_peaks_p2_indices_min)))

    all_peaks_p3_indices_max, _ = find_peaks(pendulum3)
    all_peaks_p3_indices_min, _ = find_peaks(-pendulum3)
    all_peaks_p3_indices = np.sort(np.concatenate((all_peaks_p3_indices_max, all_peaks_p3_indices_min)))

    total_window_duration = 0
    current_windows_data = []
    current_windows_metadata = []

    window_start_p1_idx = -1
    
    for i in range(len(all_peaks_p1_indices) - 1):
        current_p1_peak_idx = all_peaks_p1_indices[i]
        next_p1_peak_idx = all_peaks_p1_indices[i+1]

        t_current_p1_peak = time[current_p1_peak_idx]
        t_next_p1_peak = time[next_p1_peak_idx]

        # Condición 1: Coincidencia de picos al inicio del intervalo
        t_lower_bound_sync = t_current_p1_peak - tao
        t_upper_bound_sync = t_current_p1_peak + tao

        sync_p2 = (time[all_peaks_p2_indices] >= t_lower_bound_sync) & \
                  (time[all_peaks_p2_indices] <= t_upper_bound_sync)
        sync_p3 = (time[all_peaks_p3_indices] >= t_lower_bound_sync) & \
                  (time[all_peaks_p3_indices] <= t_upper_bound_sync)
        
        coincidence_at_current_peak = np.any(sync_p2) and np.any(sync_p3)

        # Condición 2: No hay picos adicionales en P2 ni P3 entre current_p1_peak_idx y next_p1_peak_idx
        interval_start_time = time[current_p1_peak_idx]
        interval_end_time = time[next_p1_peak_idx]

        peaks_p2_in_interval_mask = (time[all_peaks_p2_indices] > interval_start_time) & \
                                     (time[all_peaks_p2_indices] < interval_end_time)
        has_extra_peaks_p2 = np.any(peaks_p2_in_interval_mask)

        peaks_p3_in_interval_mask = (time[all_peaks_p3_indices] > interval_start_time) & \
                                     (time[all_peaks_p3_indices] < interval_end_time)
        has_extra_peaks_p3 = np.any(peaks_p3_in_interval_mask)

        no_extra_peaks = not has_extra_peaks_p2 and not has_extra_peaks_p3

        is_mode_normal_segment = coincidence_at_current_peak and no_extra_peaks

        if is_mode_normal_segment:
            if window_start_p1_idx == -1:
                window_start_p1_idx = current_p1_peak_idx
            
            if i == len(all_peaks_p1_indices) - 2:
                t_i = time[window_start_p1_idx]
                t_f = t_next_p1_peak
                duration = t_f - t_i
                
                window_end_data_idx = np.where(time <= t_f)[0][-1]
                data_window = df.iloc[window_start_p1_idx:window_end_data_idx+1].copy() # .copy() para evitar SettingWithCopyWarning
                
                total_window_duration += duration
                
                base_name = os.path.basename(file_path)
                file_id = base_name.split('_')[0]
                run_id = base_name.split('_')[1].split('.')[0]
                output_filename = f"{file_id}_{run_id}_{t_i:.3f}_{t_f:.3f}.tsv"
                plot_filename = f"{file_id}_{run_id}_{t_i:.3f}_{t_f:.3f}.png"

                current_windows_data.append(data_window)
                current_windows_metadata.append({
                    'ti': t_i, 'tf': t_f, 'duration': duration,
                    'output_filename': output_filename,
                    'plot_filename': plot_filename,
                    'original_file': file_path,
                    'tao_used': tao
                })
                window_start_p1_idx = -1
        else:
            if window_start_p1_idx != -1:
                t_i = time[window_start_p1_idx]
                t_f = time[current_p1_peak_idx] # El tiempo del pico de P1 donde la condición falló
                duration = t_f - t_i

                window_end_data_idx = np.where(time <= t_f)[0][-1]
                data_window = df.iloc[window_start_p1_idx:window_end_data_idx+1].copy()
                
                total_window_duration += duration

                base_name = os.path.basename(file_path)
                file_id = base_name.split('_')[0]
                run_id = base_name.split('_')[1].split('.')[0]
                output_filename = f"{file_id}_{run_id}_{t_i:.3f}_{t_f:.3f}.tsv"
                plot_filename = f"{file_id}_{run_id}_{t_i:.3f}_{t_f:.3f}.png"

                current_windows_data.append(data_window)
                current_windows_metadata.append({
                    'ti': t_i, 'tf': t_f, 'duration': duration,
                    'output_filename': output_filename,
                    'plot_filename': plot_filename,
                    'original_file': file_path,
                    'tao_used': tao
                })
                window_start_p1_idx = -1
    
    return total_window_duration, current_windows_data, current_windows_metadata

# --- Lógica principal para iterar sobre taos y archivos ---

# Crea un archivo de prueba si no tienes uno
if not os.path.exists("001_16_filtrado.tsv"):
    print("Creando archivo de prueba: 001_16_filtrado.tsv")
    test_data = """0	9.18	0.1	1.62
2.533	-9.72	0.18	0.36
2.584	-9.9	0.0	1.26
2.638	-8.1	-0.36	1.98
2.691	-5.04	-0.72	2.52
2.748	-0.54	-1.08	2.88
2.806	3.96	-1.26	3.06
2.858	7.2	-1.26	2.7
2.913	9.18	-1.44	2.16
2.968	9.18	-1.08	1.62
3.023	7.2	-0.54	1.08
3.076	3.96	0.0	0.54
3.131	-0.54	0.54	0.0
3.186	-5.04	1.08	-0.54
3.241	-8.1	1.26	-1.08
3.296	-9.72	1.44	-1.44
3.350	-9.9	1.44	-1.62
3.405	-9.18	1.26	-1.80
3.460	-7.2	1.08	-1.98
3.515	-3.96	0.72	-2.16
3.570	0.54	0.18	-2.34
3.625	5.04	-0.18	-2.52
3.680	8.1	-0.54	-2.70
3.735	9.72	-0.90	-2.88
3.790	9.9	-1.08	-3.06
3.845	9.18	-1.26	-3.24
3.900	7.2	-1.44	-3.42
3.955	3.96	-1.44	-3.60
4.010	-0.54	-1.26	-3.78
4.065	-5.04	-1.08	-3.96
4.120	-8.1	-0.72	-4.14
4.175	-9.72	-0.36	-4.32
4.230	-9.9	0.00	-4.50
4.285	-9.18	0.18	-4.68
4.340	-7.2	0.36	-4.86
4.395	-3.96	0.54	-5.04
4.450	0.54	0.72	-5.22
4.505	5.04	0.90	-5.40
4.560	8.1	1.08	-5.58
4.615	9.72	1.26	-5.76
4.670	9.9	1.44	-5.94
4.725	9.18	1.44	-6.12
4.780	7.2	1.26	-6.30
4.835	3.96	1.08	-6.48
4.890	-0.54	0.72	-6.66
4.945	-5.04	0.36	-6.84
5.000	-8.1	0.00	-7.02
5.055	-9.72	-0.18	-7.20
5.110	-9.9	-0.36	-7.38
5.165	-9.18	-0.54	-7.56
"""
    with open("001_16_filtrado.tsv", "w") as f:
        f.write(test_data)
    
    print("Creando segundo archivo de prueba: 002_17_filtrado.tsv")
    test_data_2 = """0	5.0	0.2	1.0
0.5	4.5	0.1	0.9
1.0	3.0	0.0	0.8
1.5	1.0	-0.1	0.7
2.0	-1.0	-0.2	0.6
2.5	-3.0	-0.1	0.5
3.0	-4.5	0.0	0.4
3.5	-5.0	0.1	0.3
4.0	-4.5	0.2	0.2
4.5	-3.0	0.1	0.1
5.0	-1.0	0.0	0.0
5.5	1.0	-0.1	-0.1
6.0	3.0	-0.2	-0.2
6.5	4.5	-0.1	-0.3
7.0	5.0	0.0	-0.4
7.5	4.5	0.1	-0.5
8.0	3.0	0.2	-0.6
8.5	1.0	0.1	-0.7
9.0	-1.0	0.0	-0.8
9.5	-3.0	-0.1	-0.9
10.0	-4.5	-0.2	-1.0
10.5	-5.0	-0.1	-0.9
11.0	-4.5	0.0	-0.8
11.5	-3.0	0.1	-0.7
12.0	-1.0	0.2	-0.6
12.5	1.0	0.1	-0.5
13.0	3.0	0.0	-0.4
13.5	4.5	-0.1	-0.3
14.0	5.0	-0.2	-0.2
14.5	4.5	-0.1	-0.1
15.0	3.0	0.0	0.0
"""
    with open("002_17_filtrado.tsv", "w") as f:
        f.write(test_data_2)


# Rango de valores de tao a probar
tolerances_tao = [0.05, 0.1, 0.15, 0.2] 

# Directorios de salida base
output_dir_base = "normal_mode_windows_optimized"
plot_dir_base = "normal_mode_plots_optimized"

# Limpiar directorios anteriores para asegurar que solo se guarde lo óptimo
if os.path.exists(output_dir_base):
    shutil.rmtree(output_dir_base)
os.makedirs(output_dir_base)

if os.path.exists(plot_dir_base):
    shutil.rmtree(plot_dir_base)
os.makedirs(plot_dir_base)

print(f"\nIniciando búsqueda de ventanas de modo normal optimizadas...")

# Lista para almacenar todas las ventanas óptimas encontradas, para luego ordenarlas
all_optimal_windows_summary = []

# Iterar sobre todos los archivos .tsv filtrados en el directorio actual
for file_path in glob.glob("*_filtrado.tsv"):
    print(f"\n--- Procesando archivo: {file_path} ---")
    
    best_tao = None
    max_duration = -1
    best_windows_data = []
    best_windows_metadata = []

    for tao_value in tolerances_tao:
        print(f"  Probando con tao = {tao_value:.2f} s")
        # Aquí se llama a la función que retorna la duración total y los metadatos
        duration, windows_data, windows_metadata = extract_normal_mode_windows_optimized(file_path, tao_value)
        
        print(f"    Duración total para tao={tao_value:.2f}: {duration:.3f} s")
        
        if duration > max_duration:
            max_duration = duration
            best_tao = tao_value
            best_windows_data = windows_data
            best_windows_metadata = windows_metadata # Corregido: Debe ser windows_metadata
    
    if best_tao is not None:
        print(f"\n¡{file_path}: Tao óptimo encontrado = {best_tao:.2f} s con una duración total de {max_duration:.3f} s!")
        
        # Ahora guardamos los archivos y gráficas para el mejor tao
        for window_data, window_meta in zip(best_windows_data, best_windows_metadata):
            output_path = os.path.join(output_dir_base, window_meta['output_filename'])
            plot_path = os.path.join(plot_dir_base, window_meta['plot_filename'])
            
            window_data.to_csv(output_path, sep='\t', index=False, header=False)
            print(f"  Guardado TSV: {window_meta['output_filename']}")
            
            plt.figure(figsize=(12, 6))
            plt.plot(window_data['time'], window_data['pendulum1'], label='Péndulo 1')
            plt.plot(window_data['time'], window_data['pendulum2'], label='Péndulo 2')
            plt.plot(window_data['time'], window_data['pendulum3'], label='Péndulo 3')
            plt.xlabel('Tiempo (s)')
            plt.ylabel('Ángulo (grados)')
            plt.title(f"Modo Normal - {os.path.basename(file_path).replace('_filtrado.tsv', '')} - Tiempos: {window_meta['ti']:.3f}s a {window_meta['tf']:.3f}s (Tao={best_tao:.2f}s)")
            plt.legend()
            plt.grid(True)
            plt.savefig(plot_path)
            plt.close()
            print(f"  Guardada Gráfica: {window_meta['plot_filename']}")

            # Añadir esta ventana a la lista global para el resumen final
            # Aseguramos que 'tao_used' se agregue aquí si no lo fue antes
            window_meta['tao_used_for_this_window'] = best_tao # Agregamos el tao óptimo específico para esta ventana
            all_optimal_windows_summary.append(window_meta)
    else:
        print(f"\n{file_path}: No se encontraron ventanas de modo normal para ningún tao probado.")

print("\nProceso de optimización de ventanas de modo normal completado.")

# Ordenar la lista de ventanas por duración, de mayor a menor
all_optimal_windows_summary.sort(key=lambda x: x['duration'], reverse=True)

if all_optimal_windows_summary:
    print("\n--- Ventanas de Modo Normal (Ordenadas por Duración, Mayor a Menor) ---")
    print("{:<12} {:<18} {:<12} {:<10} {:<10} {:<30}".format("Duración (s)", "Archivo Original", "Tao Usado", "T_Inicio", "T_Fin", "Nombre Archivo Guardado"))
    print("-" * 102) # Ajustar el ancho de la línea de separación
    for window in all_optimal_windows_summary:
        print("{:<12.3f} {:<18} {:<12.2f} {:<10.3f} {:<10.3f} {:<30}".format(
            window['duration'],
            os.path.basename(window['original_file']),
            window['tao_used_for_this_window'], # Usar la clave correcta para el tao
            window['ti'],
            window['tf'],
            window['output_filename']
        ))
    print("-" * 102)
else:
    print("\nNo se encontraron ventanas de modo normal en ningún archivo con los parámetros dados.")
# Out:
# Iniciando búsqueda de ventanas de modo normal optimizadas...
#
# --- Procesando archivo: 010_26_filtrado.tsv ---
#   Probando con tao = 0.05 s
#     Duración total para tao=0.05: 0.000 s
#   Probando con tao = 0.10 s
#     Duración total para tao=0.10: 5.171 s
#   Probando con tao = 0.15 s
#     Duración total para tao=0.15: 7.787 s
#   Probando con tao = 0.20 s
#     Duración total para tao=0.20: 9.487 s
#
# ¡010_26_filtrado.tsv: Tao óptimo encontrado = 0.20 s con una duración total de 9.487 s!
#   Guardado TSV: 010_26_38.378_38.925.tsv
#   Guardada Gráfica: 010_26_38.378_38.925.png
#   Guardado TSV: 010_26_44.371_44.876.tsv
#   Guardada Gráfica: 010_26_44.371_44.876.png
#   Guardado TSV: 010_26_46.682_47.243.tsv
#   Guardada Gráfica: 010_26_46.682_47.243.png
#   Guardado TSV: 010_26_49.049_49.645.tsv
#   Guardada Gráfica: 010_26_49.049_49.645.png
#   Guardado TSV: 010_26_50.294_50.846.tsv
#   Guardada Gráfica: 010_26_50.294_50.846.png
#   Guardado TSV: 010_26_52.690_53.241.tsv
#   Guardada Gráfica: 010_26_52.690_53.241.png
#   Guardado TSV: 010_26_55.054_55.606.tsv
#   Guardada Gráfica: 010_26_55.054_55.606.png
#   Guardado TSV: 010_26_57.396_58.007.tsv
#   Guardada Gráfica: 010_26_57.396_58.007.png
#   Guardado TSV: 010_26_59.806_60.395.tsv
#   Guardada Gráfica: 010_26_59.806_60.395.png
#   Guardado TSV: 010_26_61.048_61.545.tsv
#   Guardada Gráfica: 010_26_61.048_61.545.png
#   Guardado TSV: 010_26_63.390_63.942.tsv
#   Guardada Gráfica: 010_26_63.390_63.942.png
#   Guardado TSV: 010_26_67.651_68.038.tsv
#   Guardada Gráfica: 010_26_67.651_68.038.png
#   Guardado TSV: 010_26_68.810_69.180.tsv
#   Guardada Gráfica: 010_26_68.810_69.180.png
#   Guardado TSV: 010_26_69.962_70.344.tsv
#   Guardada Gráfica: 010_26_69.962_70.344.png
#   Guardado TSV: 010_26_71.824_72.215.tsv
#   Guardada Gráfica: 010_26_71.824_72.215.png
#   Guardado TSV: 010_26_74.131_74.536.tsv
#   Guardada Gráfica: 010_26_74.131_74.536.png
#   Guardado TSV: 010_26_75.246_75.596.tsv
#   Guardada Gráfica: 010_26_75.246_75.596.png
#   Guardado TSV: 010_26_77.170_77.493.tsv
#   Guardada Gráfica: 010_26_77.170_77.493.png
#   Guardado TSV: 010_26_78.313_78.690.tsv
#   Guardada Gráfica: 010_26_78.313_78.690.png
#   Guardado TSV: 010_26_80.186_80.575.tsv
#   Guardada Gráfica: 010_26_80.186_80.575.png
#
# --- Procesando archivo: 010_15_filtrado.tsv ---
#   Probando con tao = 0.05 s
#     Duración total para tao=0.05: 3.826 s
#   Probando con tao = 0.10 s
#     Duración total para tao=0.10: 8.095 s
#   Probando con tao = 0.15 s
#     Duración total para tao=0.15: 11.701 s
#   Probando con tao = 0.20 s
#     Duración total para tao=0.20: 11.701 s
#
# ¡010_15_filtrado.tsv: Tao óptimo encontrado = 0.15 s con una duración total de 11.701 s!
#   Guardado TSV: 010_15_14.222_14.706.tsv
#   Guardada Gráfica: 010_15_14.222_14.706.png
#   Guardado TSV: 010_15_18.949_19.488.tsv
#   Guardada Gráfica: 010_15_18.949_19.488.png
#   Guardado TSV: 010_15_21.314_21.863.tsv
#   Guardada Gráfica: 010_15_21.314_21.863.png
#   Guardado TSV: 010_15_23.734_24.223.tsv
#   Guardada Gráfica: 010_15_23.734_24.223.png
#   Guardado TSV: 010_15_25.608_26.085.tsv
#   Guardada Gráfica: 010_15_25.608_26.085.png
#   Guardado TSV: 010_15_27.400_28.481.tsv
#   Guardada Gráfica: 010_15_27.400_28.481.png
#   Guardado TSV: 010_15_29.777_30.313.tsv
#   Guardada Gráfica: 010_15_29.777_30.313.png
#   Guardado TSV: 010_15_32.193_32.679.tsv
#   Guardada Gráfica: 010_15_32.193_32.679.png
#   Guardado TSV: 010_15_34.017_35.091.tsv
#   Guardada Gráfica: 010_15_34.017_35.091.png
#   Guardado TSV: 010_15_36.386_36.923.tsv
#   Guardada Gráfica: 010_15_36.386_36.923.png
#   Guardado TSV: 010_15_38.802_39.940.tsv
#   Guardada Gráfica: 010_15_38.802_39.940.png
#   Guardado TSV: 010_15_41.165_41.703.tsv
#   Guardada Gráfica: 010_15_41.165_41.703.png
#   Guardado TSV: 010_15_42.991_44.060.tsv
#   Guardada Gráfica: 010_15_42.991_44.060.png
#   Guardado TSV: 010_15_45.353_45.896.tsv
#   Guardada Gráfica: 010_15_45.353_45.896.png
#   Guardado TSV: 010_15_47.782_48.315.tsv
#   Guardada Gráfica: 010_15_47.782_48.315.png
#   Guardado TSV: 010_15_50.137_50.685.tsv
#   Guardada Gráfica: 010_15_50.137_50.685.png
#   Guardado TSV: 010_15_52.560_53.108.tsv
#   Guardada Gráfica: 010_15_52.560_53.108.png
#   Guardado TSV: 010_15_58.592_59.124.tsv
#   Guardada Gráfica: 010_15_58.592_59.124.png
#
# --- Procesando archivo: 001_66_filtrado.tsv ---
#   Probando con tao = 0.05 s
#     Duración total para tao=0.05: 1.163 s
#   Probando con tao = 0.10 s
#     Duración total para tao=0.10: 2.316 s
#   Probando con tao = 0.15 s
#     Duración total para tao=0.15: 3.456 s
#   Probando con tao = 0.20 s
#     Duración total para tao=0.20: 4.560 s
#
# ¡001_66_filtrado.tsv: Tao óptimo encontrado = 0.20 s con una duración total de 4.560 s!
#   Guardado TSV: 001_66_3.491_3.876.tsv
#   Guardada Gráfica: 001_66_3.491_3.876.png
#   Guardado TSV: 001_66_7.692_8.029.tsv
#   Guardada Gráfica: 001_66_7.692_8.029.png
#   Guardado TSV: 001_66_14.119_14.494.tsv
#   Guardada Gráfica: 001_66_14.119_14.494.png
#   Guardado TSV: 001_66_16.424_17.181.tsv
#   Guardada Gráfica: 001_66_16.424_17.181.png
#   Guardado TSV: 001_66_32.014_32.395.tsv
#   Guardada Gráfica: 001_66_32.014_32.395.png
#   Guardado TSV: 001_66_33.922_34.309.tsv
#   Guardada Gráfica: 001_66_33.922_34.309.png
#   Guardado TSV: 001_66_43.058_43.455.tsv
#   Guardada Gráfica: 001_66_43.058_43.455.png
#   Guardado TSV: 001_66_44.949_45.330.tsv
#   Guardada Gráfica: 001_66_44.949_45.330.png
#   Guardado TSV: 001_66_46.835_47.613.tsv
#   Guardada Gráfica: 001_66_46.835_47.613.png
#   Guardado TSV: 001_66_62.423_62.805.tsv
#   Guardada Gráfica: 001_66_62.423_62.805.png
#
# --- Procesando archivo: 111_11_filtrado.tsv ---
#   Probando con tao = 0.05 s
#     Duración total para tao=0.05: 0.000 s
#   Probando con tao = 0.10 s
#     Duración total para tao=0.10: 0.769 s
#   Probando con tao = 0.15 s
#     Duración total para tao=0.15: 1.551 s
#   Probando con tao = 0.20 s
#     Duración total para tao=0.20: 2.700 s
#
# ¡111_11_filtrado.tsv: Tao óptimo encontrado = 0.20 s con una duración total de 2.700 s!
#   Guardado TSV: 111_11_26.053_26.438.tsv
#   Guardada Gráfica: 111_11_26.053_26.438.png
#   Guardado TSV: 111_11_27.326_27.712.tsv
#   Guardada Gráfica: 111_11_27.326_27.712.png
#   Guardado TSV: 111_11_59.742_60.126.tsv
#   Guardada Gráfica: 111_11_59.742_60.126.png
#   Guardado TSV: 111_11_61.445_61.829.tsv
#   Guardada Gráfica: 111_11_61.445_61.829.png
#   Guardado TSV: 111_11_64.417_64.802.tsv
#   Guardada Gráfica: 111_11_64.417_64.802.png
#   Guardado TSV: 111_11_90.809_91.206.tsv
#   Guardada Gráfica: 111_11_90.809_91.206.png
#   Guardado TSV: 111_11_92.078_92.457.tsv
#   Guardada Gráfica: 111_11_92.078_92.457.png
#
# --- Procesando archivo: 101_16_filtrado.tsv ---
#   Probando con tao = 0.05 s
#     Duración total para tao=0.05: 0.718 s
#   Probando con tao = 0.10 s
#     Duración total para tao=0.10: 3.019 s
#   Probando con tao = 0.15 s
#     Duración total para tao=0.15: 3.792 s
#   Probando con tao = 0.20 s
#     Duración total para tao=0.20: 4.552 s
#
# ¡101_16_filtrado.tsv: Tao óptimo encontrado = 0.20 s con una duración total de 4.552 s!
#   Guardado TSV: 101_16_14.267_14.659.tsv
#   Guardada Gráfica: 101_16_14.267_14.659.png
#   Guardado TSV: 101_16_18.477_18.856.tsv
#   Guardada Gráfica: 101_16_18.477_18.856.png
#   Guardado TSV: 101_16_22.650_23.035.tsv
#   Guardada Gráfica: 101_16_22.650_23.035.png
#   Guardado TSV: 101_16_26.823_27.200.tsv
#   Guardada Gráfica: 101_16_26.823_27.200.png
#   Guardado TSV: 101_16_34.034_34.411.tsv
#   Guardada Gráfica: 101_16_34.034_34.411.png
#   Guardado TSV: 101_16_41.641_42.032.tsv
#   Guardada Gráfica: 101_16_41.641_42.032.png
#   Guardado TSV: 101_16_45.432_46.196.tsv
#   Guardada Gráfica: 101_16_45.432_46.196.png
#   Guardado TSV: 101_16_49.612_50.339.tsv
#   Guardada Gráfica: 101_16_49.612_50.339.png
#   Guardado TSV: 101_16_53.018_53.395.tsv
#   Guardada Gráfica: 101_16_53.018_53.395.png
#   Guardado TSV: 101_16_53.799_54.182.tsv
#   Guardada Gráfica: 101_16_53.799_54.182.png
#
# --- Procesando archivo: 010_66_filtrado.tsv ---
#   Probando con tao = 0.05 s
#     Duración total para tao=0.05: 3.777 s
#   Probando con tao = 0.10 s
#     Duración total para tao=0.10: 9.239 s
#   Probando con tao = 0.15 s
#     Duración total para tao=0.15: 12.386 s
#   Probando con tao = 0.20 s
#     Duración total para tao=0.20: 14.068 s
#
# ¡010_66_filtrado.tsv: Tao óptimo encontrado = 0.20 s con una duración total de 14.068 s!
#   Guardado TSV: 010_66_33.076_33.581.tsv
#   Guardada Gráfica: 010_66_33.076_33.581.png
#   Guardado TSV: 010_66_34.930_35.369.tsv
#   Guardada Gráfica: 010_66_34.930_35.369.png
#   Guardado TSV: 010_66_39.569_40.010.tsv
#   Guardada Gráfica: 010_66_39.569_40.010.png
#   Guardado TSV: 010_66_45.984_46.542.tsv
#   Guardada Gráfica: 010_66_45.984_46.542.png
#   Guardado TSV: 010_66_48.344_48.914.tsv
#   Guardada Gráfica: 010_66_48.344_48.914.png
#   Guardado TSV: 010_66_50.135_50.695.tsv
#   Guardada Gráfica: 010_66_50.135_50.695.png
#   Guardado TSV: 010_66_52.491_53.043.tsv
#   Guardada Gráfica: 010_66_52.491_53.043.png
#   Guardado TSV: 010_66_56.622_57.138.tsv
#   Guardada Gráfica: 010_66_56.622_57.138.png
#   Guardado TSV: 010_66_60.759_61.257.tsv
#   Guardada Gráfica: 010_66_60.759_61.257.png
#   Guardado TSV: 010_66_63.107_63.603.tsv
#   Guardada Gráfica: 010_66_63.107_63.603.png
#   Guardado TSV: 010_66_64.843_65.402.tsv
#   Guardada Gráfica: 010_66_64.843_65.402.png
#   Guardado TSV: 010_66_67.194_67.701.tsv
#   Guardada Gráfica: 010_66_67.194_67.701.png
#   Guardado TSV: 010_66_68.963_69.504.tsv
#   Guardada Gráfica: 010_66_68.963_69.504.png
#   Guardado TSV: 010_66_74.180_74.791.tsv
#   Guardada Gráfica: 010_66_74.180_74.791.png
#   Guardado TSV: 010_66_75.950_76.498.tsv
#   Guardada Gráfica: 010_66_75.950_76.498.png
#   Guardado TSV: 010_66_77.168_77.707.tsv
#   Guardada Gráfica: 010_66_77.168_77.707.png
#   Guardado TSV: 010_66_80.076_80.627.tsv
#   Guardada Gráfica: 010_66_80.076_80.627.png
#   Guardado TSV: 010_66_83.044_83.588.tsv
#   Guardada Gráfica: 010_66_83.044_83.588.png
#   Guardado TSV: 010_66_84.156_85.335.tsv
#   Guardada Gráfica: 010_66_84.156_85.335.png
#   Guardado TSV: 010_66_86.547_87.092.tsv
#   Guardada Gráfica: 010_66_86.547_87.092.png
#   Guardado TSV: 010_66_88.908_89.447.tsv
#   Guardada Gráfica: 010_66_88.908_89.447.png
#   Guardado TSV: 010_66_90.663_91.218.tsv
#   Guardada Gráfica: 010_66_90.663_91.218.png
#   Guardado TSV: 010_66_92.381_93.550.tsv
#   Guardada Gráfica: 010_66_92.381_93.550.png
#   Guardado TSV: 010_66_94.773_95.319.tsv
#   Guardada Gráfica: 010_66_94.773_95.319.png
#
# --- Procesando archivo: 001_16_filtrado.tsv ---
#   Probando con tao = 0.05 s
#     Duración total para tao=0.05: 1.125 s
#   Probando con tao = 0.10 s
#     Duración total para tao=0.10: 2.606 s
#   Probando con tao = 0.15 s
#     Duración total para tao=0.15: 4.427 s
#   Probando con tao = 0.20 s
#     Duración total para tao=0.20: 6.219 s
#
# ¡001_16_filtrado.tsv: Tao óptimo encontrado = 0.20 s con una duración total de 6.219 s!
#   Guardado TSV: 001_16_20.078_20.399.tsv
#   Guardada Gráfica: 001_16_20.078_20.399.png
#   Guardado TSV: 001_16_32.577_32.954.tsv
#   Guardada Gráfica: 001_16_32.577_32.954.png
#   Guardado TSV: 001_16_36.758_37.128.tsv
#   Guardada Gráfica: 001_16_36.758_37.128.png
#   Guardado TSV: 001_16_40.965_41.339.tsv
#   Guardada Gráfica: 001_16_40.965_41.339.png
#   Guardado TSV: 001_16_44.730_45.475.tsv
#   Guardada Gráfica: 001_16_44.730_45.475.png
#   Guardado TSV: 001_16_48.925_49.641.tsv
#   Guardada Gráfica: 001_16_48.925_49.641.png
#   Guardado TSV: 001_16_53.458_53.822.tsv
#   Guardada Gráfica: 001_16_53.458_53.822.png
#   Guardado TSV: 001_16_57.638_58.004.tsv
#   Guardada Gráfica: 001_16_57.638_58.004.png
#   Guardado TSV: 001_16_61.419_61.789.tsv
#   Guardada Gráfica: 001_16_61.419_61.789.png
#   Guardado TSV: 001_16_64.846_65.177.tsv
#   Guardada Gráfica: 001_16_64.846_65.177.png
#   Guardado TSV: 001_16_65.590_65.965.tsv
#   Guardada Gráfica: 001_16_65.590_65.965.png
#   Guardado TSV: 001_16_68.987_69.357.tsv
#   Guardada Gráfica: 001_16_68.987_69.357.png
#   Guardado TSV: 001_16_69.746_70.121.tsv
#   Guardada Gráfica: 001_16_69.746_70.121.png
#   Guardado TSV: 001_16_73.159_73.542.tsv
#   Guardada Gráfica: 001_16_73.159_73.542.png
#   Guardado TSV: 001_16_73.907_74.289.tsv
#   Guardada Gráfica: 001_16_73.907_74.289.png
#
# Proceso de optimización de ventanas de modo normal completado.
#
# --- Ventanas de Modo Normal (Ordenadas por Duración, Mayor a Menor) ---
# Duración (s) Archivo Original   Tao Usado    T_Inicio   T_Fin      Nombre Archivo Guardado
# ------------------------------------------------------------------------------------------------------
# 1.179        010_66_filtrado.tsv 0.20         84.156     85.335     010_66_84.156_85.335.tsv
# 1.169        010_66_filtrado.tsv 0.20         92.381     93.550     010_66_92.381_93.550.tsv
# 1.138        010_15_filtrado.tsv 0.15         38.802     39.940     010_15_38.802_39.940.tsv
# 1.081        010_15_filtrado.tsv 0.15         27.400     28.481     010_15_27.400_28.481.tsv
# 1.074        010_15_filtrado.tsv 0.15         34.017     35.091     010_15_34.017_35.091.tsv
# 1.069        010_15_filtrado.tsv 0.15         42.991     44.060     010_15_42.991_44.060.tsv
# 0.778        001_66_filtrado.tsv 0.20         46.835     47.613     001_66_46.835_47.613.tsv
# 0.764        101_16_filtrado.tsv 0.20         45.432     46.196     101_16_45.432_46.196.tsv
# 0.757        001_66_filtrado.tsv 0.20         16.424     17.181     001_66_16.424_17.181.tsv
# 0.745        001_16_filtrado.tsv 0.20         44.730     45.475     001_16_44.730_45.475.tsv
# 0.727        101_16_filtrado.tsv 0.20         49.612     50.339     101_16_49.612_50.339.tsv
# 0.716        001_16_filtrado.tsv 0.20         48.925     49.641     001_16_48.925_49.641.tsv
# 0.611        010_26_filtrado.tsv 0.20         57.396     58.007     010_26_57.396_58.007.tsv
# 0.611        010_66_filtrado.tsv 0.20         74.180     74.791     010_66_74.180_74.791.tsv
# 0.596        010_26_filtrado.tsv 0.20         49.049     49.645     010_26_49.049_49.645.tsv
# 0.589        010_26_filtrado.tsv 0.20         59.806     60.395     010_26_59.806_60.395.tsv
# 0.570        010_66_filtrado.tsv 0.20         48.344     48.914     010_66_48.344_48.914.tsv
# 0.561        010_26_filtrado.tsv 0.20         46.682     47.243     010_26_46.682_47.243.tsv
# 0.560        010_66_filtrado.tsv 0.20         50.135     50.695     010_66_50.135_50.695.tsv
# 0.559        010_66_filtrado.tsv 0.20         64.843     65.402     010_66_64.843_65.402.tsv
# 0.558        010_66_filtrado.tsv 0.20         45.984     46.542     010_66_45.984_46.542.tsv
# 0.555        010_66_filtrado.tsv 0.20         90.663     91.218     010_66_90.663_91.218.tsv
# 0.552        010_26_filtrado.tsv 0.20         50.294     50.846     010_26_50.294_50.846.tsv
# 0.552        010_26_filtrado.tsv 0.20         55.054     55.606     010_26_55.054_55.606.tsv
# 0.552        010_26_filtrado.tsv 0.20         63.390     63.942     010_26_63.390_63.942.tsv
# 0.552        010_66_filtrado.tsv 0.20         52.491     53.043     010_66_52.491_53.043.tsv
# 0.551        010_26_filtrado.tsv 0.20         52.690     53.241     010_26_52.690_53.241.tsv
# 0.551        010_66_filtrado.tsv 0.20         80.076     80.627     010_66_80.076_80.627.tsv
# 0.549        010_15_filtrado.tsv 0.15         21.314     21.863     010_15_21.314_21.863.tsv
# 0.548        010_15_filtrado.tsv 0.15         50.137     50.685     010_15_50.137_50.685.tsv
# 0.548        010_66_filtrado.tsv 0.20         75.950     76.498     010_66_75.950_76.498.tsv
# 0.548        010_15_filtrado.tsv 0.15         52.560     53.108     010_15_52.560_53.108.tsv
# 0.547        010_26_filtrado.tsv 0.20         38.378     38.925     010_26_38.378_38.925.tsv
# 0.546        010_66_filtrado.tsv 0.20         94.773     95.319     010_66_94.773_95.319.tsv
# 0.545        010_66_filtrado.tsv 0.20         86.547     87.092     010_66_86.547_87.092.tsv
# 0.544        010_66_filtrado.tsv 0.20         83.044     83.588     010_66_83.044_83.588.tsv
# 0.543        010_15_filtrado.tsv 0.15         45.353     45.896     010_15_45.353_45.896.tsv
# 0.541        010_66_filtrado.tsv 0.20         68.963     69.504     010_66_68.963_69.504.tsv
# 0.539        010_66_filtrado.tsv 0.20         88.908     89.447     010_66_88.908_89.447.tsv
# 0.539        010_15_filtrado.tsv 0.15         18.949     19.488     010_15_18.949_19.488.tsv
# 0.539        010_66_filtrado.tsv 0.20         77.168     77.707     010_66_77.168_77.707.tsv
# 0.538        010_15_filtrado.tsv 0.15         41.165     41.703     010_15_41.165_41.703.tsv
# 0.537        010_15_filtrado.tsv 0.15         36.386     36.923     010_15_36.386_36.923.tsv
# 0.536        010_15_filtrado.tsv 0.15         29.777     30.313     010_15_29.777_30.313.tsv
# 0.533        010_15_filtrado.tsv 0.15         47.782     48.315     010_15_47.782_48.315.tsv
# 0.532        010_15_filtrado.tsv 0.15         58.592     59.124     010_15_58.592_59.124.tsv
# 0.516        010_66_filtrado.tsv 0.20         56.622     57.138     010_66_56.622_57.138.tsv
# 0.507        010_66_filtrado.tsv 0.20         67.194     67.701     010_66_67.194_67.701.tsv
# 0.505        010_66_filtrado.tsv 0.20         33.076     33.581     010_66_33.076_33.581.tsv
# 0.505        010_26_filtrado.tsv 0.20         44.371     44.876     010_26_44.371_44.876.tsv
# 0.498        010_66_filtrado.tsv 0.20         60.759     61.257     010_66_60.759_61.257.tsv
# 0.497        010_26_filtrado.tsv 0.20         61.048     61.545     010_26_61.048_61.545.tsv
# 0.496        010_66_filtrado.tsv 0.20         63.107     63.603     010_66_63.107_63.603.tsv
# 0.489        010_15_filtrado.tsv 0.15         23.734     24.223     010_15_23.734_24.223.tsv
# 0.486        010_15_filtrado.tsv 0.15         32.193     32.679     010_15_32.193_32.679.tsv
# 0.484        010_15_filtrado.tsv 0.15         14.222     14.706     010_15_14.222_14.706.tsv
# 0.477        010_15_filtrado.tsv 0.15         25.608     26.085     010_15_25.608_26.085.tsv
# 0.441        010_66_filtrado.tsv 0.20         39.569     40.010     010_66_39.569_40.010.tsv
# 0.439        010_66_filtrado.tsv 0.20         34.930     35.369     010_66_34.930_35.369.tsv
# 0.405        010_26_filtrado.tsv 0.20         74.131     74.536     010_26_74.131_74.536.tsv
# 0.397        111_11_filtrado.tsv 0.20         90.809     91.206     111_11_90.809_91.206.tsv
# 0.397        001_66_filtrado.tsv 0.20         43.058     43.455     001_66_43.058_43.455.tsv
# 0.392        101_16_filtrado.tsv 0.20         14.267     14.659     101_16_14.267_14.659.tsv
# 0.391        010_26_filtrado.tsv 0.20         71.824     72.215     010_26_71.824_72.215.tsv
# 0.391        101_16_filtrado.tsv 0.20         41.641     42.032     101_16_41.641_42.032.tsv
# 0.389        010_26_filtrado.tsv 0.20         80.186     80.575     010_26_80.186_80.575.tsv
# 0.387        010_26_filtrado.tsv 0.20         67.651     68.038     010_26_67.651_68.038.tsv
# 0.387        001_66_filtrado.tsv 0.20         33.922     34.309     001_66_33.922_34.309.tsv
# 0.386        111_11_filtrado.tsv 0.20         27.326     27.712     111_11_27.326_27.712.tsv
# 0.385        111_11_filtrado.tsv 0.20         64.417     64.802     111_11_64.417_64.802.tsv
# 0.385        101_16_filtrado.tsv 0.20         22.650     23.035     101_16_22.650_23.035.tsv
# 0.385        001_66_filtrado.tsv 0.20         3.491      3.876      001_66_3.491_3.876.tsv
# 0.385        111_11_filtrado.tsv 0.20         26.053     26.438     111_11_26.053_26.438.tsv
# 0.384        111_11_filtrado.tsv 0.20         59.742     60.126     111_11_59.742_60.126.tsv
# 0.384        111_11_filtrado.tsv 0.20         61.445     61.829     111_11_61.445_61.829.tsv
# 0.383        101_16_filtrado.tsv 0.20         53.799     54.182     101_16_53.799_54.182.tsv
# 0.383        001_16_filtrado.tsv 0.20         73.159     73.542     001_16_73.159_73.542.tsv
# 0.382        001_16_filtrado.tsv 0.20         73.907     74.289     001_16_73.907_74.289.tsv
# 0.382        001_66_filtrado.tsv 0.20         62.423     62.805     001_66_62.423_62.805.tsv
# 0.382        010_26_filtrado.tsv 0.20         69.962     70.344     010_26_69.962_70.344.tsv
# 0.381        001_66_filtrado.tsv 0.20         32.014     32.395     001_66_32.014_32.395.tsv
# 0.381        001_66_filtrado.tsv 0.20         44.949     45.330     001_66_44.949_45.330.tsv
# 0.379        101_16_filtrado.tsv 0.20         18.477     18.856     101_16_18.477_18.856.tsv
# 0.379        111_11_filtrado.tsv 0.20         92.078     92.457     111_11_92.078_92.457.tsv
# 0.377        101_16_filtrado.tsv 0.20         34.034     34.411     101_16_34.034_34.411.tsv
# 0.377        101_16_filtrado.tsv 0.20         53.018     53.395     101_16_53.018_53.395.tsv
# 0.377        001_16_filtrado.tsv 0.20         32.577     32.954     001_16_32.577_32.954.tsv
# 0.377        101_16_filtrado.tsv 0.20         26.823     27.200     101_16_26.823_27.200.tsv
# 0.377        010_26_filtrado.tsv 0.20         78.313     78.690     010_26_78.313_78.690.tsv
# 0.375        001_66_filtrado.tsv 0.20         14.119     14.494     001_66_14.119_14.494.tsv
# 0.375        001_16_filtrado.tsv 0.20         65.590     65.965     001_16_65.590_65.965.tsv
# 0.375        001_16_filtrado.tsv 0.20         69.746     70.121     001_16_69.746_70.121.tsv
# 0.374        001_16_filtrado.tsv 0.20         40.965     41.339     001_16_40.965_41.339.tsv
# 0.370        010_26_filtrado.tsv 0.20         68.810     69.180     010_26_68.810_69.180.tsv
# 0.370        001_16_filtrado.tsv 0.20         61.419     61.789     001_16_61.419_61.789.tsv
# 0.370        001_16_filtrado.tsv 0.20         68.987     69.357     001_16_68.987_69.357.tsv
# 0.370        001_16_filtrado.tsv 0.20         36.758     37.128     001_16_36.758_37.128.tsv
# 0.366        001_16_filtrado.tsv 0.20         57.638     58.004     001_16_57.638_58.004.tsv
# 0.364        001_16_filtrado.tsv 0.20         53.458     53.822     001_16_53.458_53.822.tsv
# 0.350        010_26_filtrado.tsv 0.20         75.246     75.596     010_26_75.246_75.596.tsv
# 0.337        001_66_filtrado.tsv 0.20         7.692      8.029      001_66_7.692_8.029.tsv
# 0.331        001_16_filtrado.tsv 0.20         64.846     65.177     001_16_64.846_65.177.tsv
# 0.323        010_26_filtrado.tsv 0.20         77.170     77.493     010_26_77.170_77.493.tsv
# 0.321        001_16_filtrado.tsv 0.20         20.078     20.399     001_16_20.078_20.399.tsv
# ------------------------------------------------------------------------------------------------------
